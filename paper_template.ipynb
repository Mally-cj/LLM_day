# %% [markdown]
# 2025-10-26 23:53:44 Sunday
#
#
# ### 基础：大模型的memory
#
# 对于普通大模型 / LLM Agent 而言，
# Memory 通常分为三层：
# 短期记忆（Short-Term） — 当前上下文，放prompt里
# 长期记忆（Long-Term） — 外部知识存储，放rag里，
# 语义记忆（Semantic / Episodic） — 抽象知识、总结偏好，放类似json这样的文件里，调用llm检索和问题相关性，再加入到prompt中。
#
#         |

# %% [markdown]
# # 📘 论文阅读笔记
#
# ## 📄 基本信息
# - **标题**：
# - **作者**：
# - **单位**：
# - **年份**：
# - **论文链接**：
# - **模型参考**：
#
# ---
#
# ## 🎯 一句话总结
# > 简要说明论文的核心创新与主要贡献。
#
# ---
#
# ## 🧩 1. 研究背景与问题定义
#
# ### 🎯 研究目标
# - 简述研究想解决的问题与核心目标。
#
# ### ⚠️ 现有问题
# - 概述现有方法的不足或待解决的痛点。
#
# ### 💡 作者动机
# - 说明作者提出新方法的原因与出发点。
#
# ---
#
# ## ⚙️ 2. 方法概述（核心创新）
#
# ### 🌈 核心思想
# - 简述方法的关键思路与总体框架。
#
# ### 🔍 方法细节
# - 给出关键公式或结构说明，例如：
#   $$
#   J(\theta) = \mathbb{E}_{x,y \sim \pi_{\text{old}}}
#   \left[
#   \frac{1}{|y|} \sum_t
#   \min\left(
#   w_t(\theta)A_t,
#   \text{clip}(w_t(\theta), 1-\epsilon, 1+\epsilon)A_t
#   \right)
#   \right]
#   $$
# - 描述算法或模型的主要流程。
#
# ### ✅ 方法优点
# 1.
# 2.
# 3.
#
# ---
#
# ## 🔬 3. 实验与结果分析
#
# ### 📊 数据与任务
# - 说明实验使用的数据集与任务设置。
#
# ### ⚔️ 对比方法
# - 列出主要的 baseline 与改进方法。
#
# ### 📈 实验结果
# - 总结实验结果、性能提升或关键指标变化。
#
# ---
#
# ## 💡 4. 主要结论与启示
# - 总结论文的主要发现与启示。
# - 说明方法的局限性或未来可改进方向。
#
# ---

# %% [markdown]
# ### 大模型的memory
#
# 对于普通大模型 / LLM Agent 而言，
# Memory 通常分为三层：
# 短期记忆（Short-Term） — 当前上下文，放prompt里
# 长期记忆（Long-Term） — 外部知识存储，放rag里，
# 语义记忆（Semantic / Episodic） — 抽象知识、总结偏好，放类似json这样的文件里，调用llm检索和问题相关性，再加入到prompt中。
#
#         |
